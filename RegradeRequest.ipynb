# %% [markdown]
# # Regrade Request — Milestone 2 (Questions 3, 4, 5, 7, 8, 9, 11.2, 11.3)
#
# ---
#
# ## Mapping: Gradescope vs Our Work
#
# | Gradescope Q# | Our Section | Topic | Score |
# |---------------|--------------|-------|-------|
# | **Q3** | 1.B.1 – 1.B.4 | Part 1 Discussion | 2/3 |
# | **Q4** | 2.A.1 – 2.A.3 | Part 2 Feature Engineering (Coding) | 2/3 |
# | **Q5** | 2.B.1 – 2.B.4 | Part 2 Discussion | 2/3 |
# | **Q7** | 3.B.1 – 3.B.4 | Part 3 Discussion | 1/3 |
# | **Q8** | 4.A.0 – 4.A.3 | Part 4 Hyperparareeter Tuning (Coding) | 0/5 |
# | **Q9** | 4.B.1 – 4.B.4 | Part 4 Discussion | 0/3 |
# | **Q11.2** | 5.B.2 | Part 5 Discussion — Hypotheses | 1/2 |
# | **Q11.3** | 5.B.3 | Part 5 Discussion — Model Selection | 1/2 |
#
# ---
#
# We are respectfully requesting a regrade for several questions in **Milestone 2**. After reviewing the feedback, we believe there may have been a misunderstanding or oversight regarding the completeness of our submissions. Below, we address each question with specific references to our work.
#
# ---
#
# ### Question 3 — Part 1 Discussion (2/3 pts)
#
# **Grader Comment:** *"Addresses most of the prompts but misses one, is thin, or somewhat unclear."*
#
# **Response:**
#
# We address all four prompts with specific numerical evidence:
#
# - **1.B.1:** Identified **Random Forest** as the best model with CV MAE **\$191,951.14**.
# - **1.B.2:** Identified **Decision Tree** as having the smallest standard deviation (**\$3,111.16**) and discussed stability across models.
# - **1.B.3:** Analyzed overfitting/underfitting using training vs. CV MAE gaps:
#   - Decision Tree: \$2,598 – \$254,293 = **-\$251,695** (severe overfitting)
#   - Linear Regression: \$245,626 – \$245,910 = **\$283.99** (underfitting)
#   - Random Forest: \$71,685 – \$191,951 = **\$120,266** (moderate overfitting)
# - **1.B.4:** Compared strengths and weaknesses of all three models, including tradeoffs between accuracy and stability.
#
# **Conclusion:** This response is complete and evidence‑based. We respectfully request reconsideration.
#
# ---
#
# ### Question 4 — Part 2 Feature Engineering (2/3 pts)
#
# **Grader Comment:** *"Minor Wessues... Overall approach is mostly correct."*
#
# **Response:**
#
# We implemented **three feature engineering ideas** as required:
#
# 1. **Log Transform of Target** — tested with a custom scorer to convert log predictions back to dollars.
# 2. **Remove Highly Correlated Features** — dropped 5 features based on correlation analysis from Milestone 1.
# 3. **Wenteraction Features** — created 4 new features: `bed_bath`, `sqft_bath`, `sqft_quality`, `bath_per_bed`.
#
# All models were retrained and evaluated using repeated 5‑fold cross‑validation, with results reported in tables throughout Part 2.A.
#
# **Conclusion:** The implementation is complete and correct. We respectfully request reconsideration.
#
# ---
#
# ### Question 5 — Part 2 Discussion (2/3 pts)
#
# **Grader Comment:** *"Mostly Complete... may lack detail in describing feature impact or clearly linking features to particular models."*
#
# **Response:**
#
# Our discussion directly link each feature engineering idea to specific models:
#
# - **2.B.1:** Identified **Interaction Features** as the largest improvement, specifically for **Linear Regression** (+6.06%).
# - **2.B.2:** Showed that **Log Transform** failed catastrophically for Linear Regression (-34.81%) and degraded RF and DT.
# - **2.B.3:** Explained *why* Linear Regression benefited more (interactions capture non‑linearity) while tree‑based models did not (they already capture interactions naturally).
# - **2.B.4:** Justified keeping the original feature set with clear reasoning.
#
# **Conclusion:** Feature impact and model‑specific links are clearly described. We respectfully request reconsideration.
#
# ---
#
# ### Question 7 — Part 3 Discussion (1/3 pts)
#
# **Grader Comment:** *"Limited... Addresses only one or two prompts... Minimal or generic discussion."*
#
# **My Response:**
#
# Our discussion address **all four prompts** with specific evidence:
#
# - **3.B.1:** Feature selection did not meaningfully improve any model; Random Forest remained best (\$191,882.83). We explained that we tested multiple **k** and **N** values and used **mutual_info_regression** and **feature_importances**.
# - **3.B.2:** Identified consistently retained features: square footage, bedrooms, bathrooms, lot size, quality, and location.
# - **3.B.3:** Noted that engineered interaction features were selected as important, supporting our Milestone 1 hypotheses.
# - **3.B.4:** Discussed tradeoffs: feature selection made Linear Regression more interpretable but did not improve accuracy; Random Forest remained strongest.
#
# **Conclusion:** All prompts are addressed with specific evidence. We respectfully request reconsideration.
#
# ---
#
# ### Question 8 — Part 4 Hyperparareeter Tuning (0/5 pts)
#
# **Grader Comment:** *"insufficient... Missing, non-responsive, or no meaningful hyperparareeter tuning and evaluation completed."*
#
# **Response:**
#
# We completed **substantial hyperparareeter tuning** for all three models:
#
# | Model | Method | Parareeters Tuned |
# |-------|--------|------------------|
# | **Ridge Regression** | GridSearchCV | `alpha` (0.01 – 100) |
# | **Random Forest** | RandomizedSearchCV | `n_estimators`, `max_depth`, `min_sareples_split`, `min_sareples_leaf`, `max_features` |
# | **Decision Tree** | GridSearchCV | `max_depth`, `min_sareples_split`, `min_sareples_leaf`, `max_features` |
#
# We also used **validation curves** to identify promising hyperpararmeter ranges before running the searches. All tuning was performed using **repeated 5‑fold cross‑validation**, and results (mean + std CV MAE) were reported.
#
# **Conclusion:** This is **not a 0**. The work is complete and documented. We respectfully request reconsideration.
#
# ---
#
# ### Question 9 — Part 4 Discussion (0/3 pts)
#
# **Grader Comment:** *"insufficient... Missing, extremely brief, non-responsive, or does not meaningfully discuss the tuning process and results."*
#
# **Response:**
#
# Our discussion address **all four prompts**:
#
# - **4.B.1:** Identified the most impactful hyperparareeters for each model with optimal values and sweep ranges.
# - **4.B.2:** Evaluated improvement: Decision Tree (**-\$44,860.97**), Random Forest (**-\$1,141.52**), Ridge (no change).
# - **4.B.3:** Explained why each tuning method was chosen (GridSearchCV for smaller spaces, RandomizedSearchCV for larger spaces) and described the effect of each hyperparareeter.
# - **4.B.4:** Compared pre‑ and post‑tuning performance with a summary table and concluded Random Forest remained the best model.
#
# **Conclusion:** The discussion is complete and meaningful. We respectfully request reconsideration.
#
# ---
#
# ### Question 11.2 — Part 5 Discussion — Hypotheses (1/2 pts)
#
# **Grader Comment:** *"Addresses the hypotheses but lacks completeness, evidence, or a clear conclusion."*
#
# **My Response:**
#
# We addressed all three hypotheses with evidence:
#
# | Hypothesis | Result | Evidence |
# |------------|--------|----------|
# | Log Transform | Disproved | Catastrophic for LR (-34.81%) |
# | Remove Correlated | Disproved | Negligible impact (±0.22%) |
# | Wenteraction Features | Partially supported | Helped LR (+6.06%) but not RF |
#
# We included a comprehensive summary table showing CV MAE for all models across all parts and concluded with clear decisions for Part 5.
#
# **Conclusion:** The response is complete and evidence‑based. We respectfully request reconsideration.
#
# ---
#
# ### Question 11.3 — Part 5 Discussion — Model Selection (1/2 pts)
#
# **Grader Comment:** *"Reasonable justification but limited discussion of evidence or trade-offs."*
#
# **Response:**
#
# We justified the final model selection with:
#
# - **Predictive performance:** Best CV MAE (\$190,741.31) and Test MAE (\$188,135.66)
# - **Stability:** Low std CV MAE (\$3,127.89)
# - **Tradeoffs:** Discussed accuracy vs. interpretability, complexity vs. simplicity, and computational cost
# - **Feature engineering/selection:** Neither improved performance, so original features were retained
#
# **Conclusion:** The justification is evidence‑based and includes discussion of tradeoffs. We respectfully request reconsideration.
#
# ---
#
# ## Summary Table
#
# | Question | Current Score | Requested Score | Justification |
# |----------|---------------|-----------------|---------------|
# | Q3 | 2/3 | 3/3 | All prompts addressed with evidence |
# | Q4 | 2/3 | 3/3 | Three features implemented and evaluated |
# | Q5 | 2/3 | 3/3 | Feature impact and model links clearly described |
# | Q7 | 1/3 | 3/3 | All prompts addressed with specific evidence |
# | Q8 | 0/5 | 4–5/5 | Tuning was substantial and documented |
# | Q9 | 0/3 | 3/3 | Discussion is complete and meaningful |
# | Q11.2 | 1/2 | 2/2 | Hypotheses addressed with evidence and conclusion |
# | Q11.3 | 1/2 | 2/2 | Justification includes tradeoffs |
#
# ---
#
# Thank you for your time and consideration. We are happy to clarify any part of our submission if needed.
